# %% [markdown]
# The notebooks takes unseen test data and produces a multi-visit reconstruction based on the initial reconstruction (Step 01) and the previous registered scan (Step 02).
#
# A docker container was again used to run the following notebook

# %%
import subprocess

def install(name):
    subprocess.call(['pip', 'install', name])

install('nibabel')
install('scikit-learn')

import sys


import numpy as np
import os
import glob
import sys
import matplotlib.pyplot as plt
# Importing keras and data augmentation utils
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import  Adam
import pickle
import nibabel as nib
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

# Include path where reconstruction modules are defined
MY_UTILS_PATH = "../src"
if not MY_UTILS_PATH in sys.path:
    sys.path.append(MY_UTILS_PATH)

import enhancement_unet as eu

# %%
batch_size = 16
lr = 1e-4
decay = 1e-7

# %%
#model_path = '../models/enhancement_unet_sc_512x512_5x.h5'
weights_path = '../models/weights_enhancement_unet_sc_10x-recurrentvar-rnl-3.h5'
previous_path = '../data/reference_reg_10x-varnet/'
follow_up_path = '../data/predicted/10x-varnet/nib/'
reference_path = '../../../data/brain-cancer/'
out_path = '../data/predicted/10x-enhanced-varnet/'#save folder
os.makedirs(out_path, exist_ok=True)

# %%
test_files = np.loadtxt("../data/test_long.txt",dtype = str)
print(test_files)
# Out:
# [['TUM04-20170309.nii' 'TUM04-20171108.nii' 'TUM04-20180103.nii']
#  ['TUM04-20171108.nii' 'TUM04-20190328.nii' 'TUM04-20190523.nii']
#  ['TUM04-20180618.nii' 'TUM04-20181009.nii' 'TUM04-20190328.nii']
#  ['TUM20-20170928.nii' 'TUM20-20180205.nii' 'TUM20-20180402.nii']
#  ['TUM10-20170316.nii' 'TUM10-20171018.nii' 'TUM10-20180122.nii']
#  ['TUM10-20171018.nii' 'TUM10-20180122.nii' 'TUM10-20180307.nii']
#  ['TUM15-20170531.nii' 'TUM15-20170801.nii' 'TUM15-20170816.nii']]

# %%
test_files = test_files[:,1:]

# %%
test_files
# Out:
# array([['TUM04-20171108.nii', 'TUM04-20180103.nii'],
#        ['TUM04-20190328.nii', 'TUM04-20190523.nii'],
#        ['TUM04-20181009.nii', 'TUM04-20190328.nii'],
#        ['TUM20-20180205.nii', 'TUM20-20180402.nii'],
#        ['TUM10-20171018.nii', 'TUM10-20180122.nii'],
#        ['TUM10-20180122.nii', 'TUM10-20180307.nii'],
#        ['TUM15-20170801.nii', 'TUM15-20170816.nii']], dtype='<U18')

# %%
count = 0
for ii in range(test_files.shape[0]):
    ref = nib.load(reference_path + test_files[ii][1])
    aux = nib.load(os.path.join(previous_path,'elastic_' + test_files[ii,0][:-4] + "_" + test_files[ii,1][:14] +"-2.nii")).get_fdata()
    aux2 = nib.load(os.path.join(follow_up_path, test_files[ii,1][:-4] + '_predicted.nii')).get_fdata()
    aux = np.swapaxes(aux,0,2) / np.abs(aux).max()
    aux2 = np.swapaxes(aux2,0,2) / np.abs(aux2).max()
    Z,W,H = aux.shape
    count = count + aux.shape[0] - 40
    print(aux.shape, aux2.shape)
# Out:
# (160, 512, 512) (160, 512, 512)
# (163, 512, 512) (163, 512, 512)
# (152, 512, 512) (152, 512, 512)
# (179, 512, 512) (179, 512, 512)
# (142, 512, 512) (142, 512, 512)
# (156, 512, 512) (156, 512, 512)
# (165, 512, 512) (165, 512, 512)

# %%
count
# Out:
# 837

# %%
for ii in range(test_files.shape[0]):
    ref = nib.load(reference_path + test_files[ii][1])
    aux = nib.load(os.path.join(previous_path,'elastic_' + test_files[ii,0][:-4] + "_" + test_files[ii,1][:14]  +"-2.nii")).get_fdata()
    aux2 = nib.load(os.path.join(follow_up_path, test_files[ii,1][:-4] + '_predicted.nii')).get_fdata()
    aux = np.swapaxes(aux,0,2) / np.abs(aux).max()
    aux2 = np.swapaxes(aux2,0,2) / np.abs(aux2).max()
    Z,W,H = aux.shape
    print(aux.shape, aux2.shape)
    test = np.zeros((aux.shape[0],aux.shape[1],aux.shape[2],2),dtype = np.float32)
    print(test.shape)
    test[:,:,:,0] = aux
    test[:,:,:,1] = aux2

    Hpad = (8 - (H%8))//2
    Wpad = (8 - (W%8))//2

    model = eu.enhancement_unet(H=H, W=W,Hpad = Hpad, Wpad = Wpad)
    opt = Adam(learning_rate = lr,decay = decay)
    model.compile(loss = 'mse',optimizer=opt)
    model.load_weights(weights_path)
    print(model.summary())
    pred = model.predict([test,test[:,:,:,1,np.newaxis]])
    
    pred = np.swapaxes(pred,0,2)
    #pred = np.flip(pred,axis=-1)
    out_file = os.path.join(out_path,test_files[ii,1][:-4] + '_predicted-2.nii')
    img = nib.Nifti1Image(pred[:,:,:,0], ref.affine)
    nib.save(img,out_file)
    print(img.shape,ref.shape)
# Out:
# (160, 512, 512) (160, 512, 512)
# (160, 512, 512, 2)
# Model: "model_61"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_123 (InputLayer)         [(None, 512, 512, 2  0           []
#                                 )]
#
#  zero_padding2d_61 (ZeroPadding  (None, 520, 520, 2)  0          ['input_123[0][0]']
#  2D)
#
#  conv2d_1342 (Conv2D)           (None, 520, 520, 48  912         ['zero_padding2d_61[0][0]']
#                                 )
#
#  conv2d_1343 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1342[0][0]']
#                                 )
#
#  conv2d_1344 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1343[0][0]']
#                                 )
#
#  max_pooling2d_183 (MaxPooling2  (None, 260, 260, 48  0          ['conv2d_1344[0][0]']
#  D)                             )
#
#  conv2d_1345 (Conv2D)           (None, 260, 260, 64  27712       ['max_pooling2d_183[0][0]']
#                                 )
#
#  conv2d_1346 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1345[0][0]']
#                                 )
#
#  conv2d_1347 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1346[0][0]']
#                                 )
#
#  max_pooling2d_184 (MaxPooling2  (None, 130, 130, 64  0          ['conv2d_1347[0][0]']
#  D)                             )
#
#  conv2d_1348 (Conv2D)           (None, 130, 130, 12  73856       ['max_pooling2d_184[0][0]']
#                                 8)
#
#  conv2d_1349 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1348[0][0]']
#                                 8)
#
#  conv2d_1350 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1349[0][0]']
#                                 8)
#
#  max_pooling2d_185 (MaxPooling2  (None, 65, 65, 128)  0          ['conv2d_1350[0][0]']
#  D)
#
#  conv2d_1351 (Conv2D)           (None, 65, 65, 256)  295168      ['max_pooling2d_185[0][0]']
#
#  conv2d_1352 (Conv2D)           (None, 65, 65, 256)  590080      ['conv2d_1351[0][0]']
#
#  conv2d_1353 (Conv2D)           (None, 65, 65, 256)  590080      ['conv2d_1352[0][0]']
#
#  up_sampling2d_183 (UpSampling2  (None, 130, 130, 25  0          ['conv2d_1353[0][0]']
#  D)                             6)
#
#  concatenate_183 (Concatenate)  (None, 130, 130, 38  0           ['up_sampling2d_183[0][0]',
#                                 4)                                'conv2d_1350[0][0]']
#
#  conv2d_1354 (Conv2D)           (None, 130, 130, 12  442496      ['concatenate_183[0][0]']
#                                 8)
#
#  conv2d_1355 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1354[0][0]']
#                                 8)
#
#  conv2d_1356 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1355[0][0]']
#                                 8)
#
#  up_sampling2d_184 (UpSampling2  (None, 260, 260, 12  0          ['conv2d_1356[0][0]']
#  D)                             8)
#
#  concatenate_184 (Concatenate)  (None, 260, 260, 19  0           ['up_sampling2d_184[0][0]',
#                                 2)                                'conv2d_1347[0][0]']
#
#  conv2d_1357 (Conv2D)           (None, 260, 260, 64  110656      ['concatenate_184[0][0]']
#                                 )
#
#  conv2d_1358 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1357[0][0]']
#                                 )
#
#  conv2d_1359 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1358[0][0]']
#                                 )
#
#  up_sampling2d_185 (UpSampling2  (None, 520, 520, 64  0          ['conv2d_1359[0][0]']
#  D)                             )
#
#  concatenate_185 (Concatenate)  (None, 520, 520, 11  0           ['up_sampling2d_185[0][0]',
#                                 2)                                'conv2d_1344[0][0]']
#
#  conv2d_1360 (Conv2D)           (None, 520, 520, 48  48432       ['concatenate_185[0][0]']
#                                 )
#
#  conv2d_1361 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1360[0][0]']
#                                 )
#
#  conv2d_1362 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1361[0][0]']
#                                 )
#
#  conv2d_1363 (Conv2D)           (None, 520, 520, 1)  49          ['conv2d_1362[0][0]']
#
#  cropping2d_61 (Cropping2D)     (None, 512, 512, 1)  0           ['conv2d_1363[0][0]']
#
#  input_124 (InputLayer)         [(None, 512, 512, 1  0           []
#                                 )]
#
#  add_61 (Add)                   (None, 512, 512, 1)  0           ['cropping2d_61[0][0]',
#                                                                   'input_124[0][0]']
#
# ==================================================================================================
# Total params: 3,000,625
# Trainable params: 3,000,625
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (512, 512, 160) (512, 512, 160)
# (163, 512, 512) (163, 512, 512)
# (163, 512, 512, 2)
# Model: "model_62"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_125 (InputLayer)         [(None, 512, 512, 2  0           []
#                                 )]
#
#  zero_padding2d_62 (ZeroPadding  (None, 520, 520, 2)  0          ['input_125[0][0]']
#  2D)
#
#  conv2d_1364 (Conv2D)           (None, 520, 520, 48  912         ['zero_padding2d_62[0][0]']
#                                 )
#
#  conv2d_1365 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1364[0][0]']
#                                 )
#
#  conv2d_1366 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1365[0][0]']
#                                 )
#
#  max_pooling2d_186 (MaxPooling2  (None, 260, 260, 48  0          ['conv2d_1366[0][0]']
#  D)                             )
#
#  conv2d_1367 (Conv2D)           (None, 260, 260, 64  27712       ['max_pooling2d_186[0][0]']
#                                 )
#
#  conv2d_1368 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1367[0][0]']
#                                 )
#
#  conv2d_1369 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1368[0][0]']
#                                 )
#
#  max_pooling2d_187 (MaxPooling2  (None, 130, 130, 64  0          ['conv2d_1369[0][0]']
#  D)                             )
#
#  conv2d_1370 (Conv2D)           (None, 130, 130, 12  73856       ['max_pooling2d_187[0][0]']
#                                 8)
#
#  conv2d_1371 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1370[0][0]']
#                                 8)
#
#  conv2d_1372 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1371[0][0]']
#                                 8)
#
#  max_pooling2d_188 (MaxPooling2  (None, 65, 65, 128)  0          ['conv2d_1372[0][0]']
#  D)
#
#  conv2d_1373 (Conv2D)           (None, 65, 65, 256)  295168      ['max_pooling2d_188[0][0]']
#
#  conv2d_1374 (Conv2D)           (None, 65, 65, 256)  590080      ['conv2d_1373[0][0]']
#
#  conv2d_1375 (Conv2D)           (None, 65, 65, 256)  590080      ['conv2d_1374[0][0]']
#
#  up_sampling2d_186 (UpSampling2  (None, 130, 130, 25  0          ['conv2d_1375[0][0]']
#  D)                             6)
#
#  concatenate_186 (Concatenate)  (None, 130, 130, 38  0           ['up_sampling2d_186[0][0]',
#                                 4)                                'conv2d_1372[0][0]']
#
#  conv2d_1376 (Conv2D)           (None, 130, 130, 12  442496      ['concatenate_186[0][0]']
#                                 8)
#
#  conv2d_1377 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1376[0][0]']
#                                 8)
#
#  conv2d_1378 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1377[0][0]']
#                                 8)
#
#  up_sampling2d_187 (UpSampling2  (None, 260, 260, 12  0          ['conv2d_1378[0][0]']
#  D)                             8)
#
#  concatenate_187 (Concatenate)  (None, 260, 260, 19  0           ['up_sampling2d_187[0][0]',
#                                 2)                                'conv2d_1369[0][0]']
#
#  conv2d_1379 (Conv2D)           (None, 260, 260, 64  110656      ['concatenate_187[0][0]']
#                                 )
#
#  conv2d_1380 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1379[0][0]']
#                                 )
#
#  conv2d_1381 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1380[0][0]']
#                                 )
#
#  up_sampling2d_188 (UpSampling2  (None, 520, 520, 64  0          ['conv2d_1381[0][0]']
#  D)                             )
#
#  concatenate_188 (Concatenate)  (None, 520, 520, 11  0           ['up_sampling2d_188[0][0]',
#                                 2)                                'conv2d_1366[0][0]']
#
#  conv2d_1382 (Conv2D)           (None, 520, 520, 48  48432       ['concatenate_188[0][0]']
#                                 )
#
#  conv2d_1383 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1382[0][0]']
#                                 )
#
#  conv2d_1384 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1383[0][0]']
#                                 )
#
#  conv2d_1385 (Conv2D)           (None, 520, 520, 1)  49          ['conv2d_1384[0][0]']
#
#  cropping2d_62 (Cropping2D)     (None, 512, 512, 1)  0           ['conv2d_1385[0][0]']
#
#  input_126 (InputLayer)         [(None, 512, 512, 1  0           []
#                                 )]
#
#  add_62 (Add)                   (None, 512, 512, 1)  0           ['cropping2d_62[0][0]',
#                                                                   'input_126[0][0]']
#
# ==================================================================================================
# Total params: 3,000,625
# Trainable params: 3,000,625
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (512, 512, 163) (512, 512, 163)
# (152, 512, 512) (152, 512, 512)
# (152, 512, 512, 2)
# Model: "model_63"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_127 (InputLayer)         [(None, 512, 512, 2  0           []
#                                 )]
#
#  zero_padding2d_63 (ZeroPadding  (None, 520, 520, 2)  0          ['input_127[0][0]']
#  2D)
#
#  conv2d_1386 (Conv2D)           (None, 520, 520, 48  912         ['zero_padding2d_63[0][0]']
#                                 )
#
#  conv2d_1387 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1386[0][0]']
#                                 )
#
#  conv2d_1388 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1387[0][0]']
#                                 )
#
#  max_pooling2d_189 (MaxPooling2  (None, 260, 260, 48  0          ['conv2d_1388[0][0]']
#  D)                             )
#
#  conv2d_1389 (Conv2D)           (None, 260, 260, 64  27712       ['max_pooling2d_189[0][0]']
#                                 )
#
#  conv2d_1390 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1389[0][0]']
#                                 )
#
#  conv2d_1391 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1390[0][0]']
#                                 )
#
#  max_pooling2d_190 (MaxPooling2  (None, 130, 130, 64  0          ['conv2d_1391[0][0]']
#  D)                             )
#
#  conv2d_1392 (Conv2D)           (None, 130, 130, 12  73856       ['max_pooling2d_190[0][0]']
#                                 8)
#
#  conv2d_1393 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1392[0][0]']
#                                 8)
#
#  conv2d_1394 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1393[0][0]']
#                                 8)
#
#  max_pooling2d_191 (MaxPooling2  (None, 65, 65, 128)  0          ['conv2d_1394[0][0]']
#  D)
#
#  conv2d_1395 (Conv2D)           (None, 65, 65, 256)  295168      ['max_pooling2d_191[0][0]']
#
#  conv2d_1396 (Conv2D)           (None, 65, 65, 256)  590080      ['conv2d_1395[0][0]']
#
#  conv2d_1397 (Conv2D)           (None, 65, 65, 256)  590080      ['conv2d_1396[0][0]']
#
#  up_sampling2d_189 (UpSampling2  (None, 130, 130, 25  0          ['conv2d_1397[0][0]']
#  D)                             6)
#
#  concatenate_189 (Concatenate)  (None, 130, 130, 38  0           ['up_sampling2d_189[0][0]',
#                                 4)                                'conv2d_1394[0][0]']
#
#  conv2d_1398 (Conv2D)           (None, 130, 130, 12  442496      ['concatenate_189[0][0]']
#                                 8)
#
#  conv2d_1399 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1398[0][0]']
#                                 8)
#
#  conv2d_1400 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1399[0][0]']
#                                 8)
#
#  up_sampling2d_190 (UpSampling2  (None, 260, 260, 12  0          ['conv2d_1400[0][0]']
#  D)                             8)
#
#  concatenate_190 (Concatenate)  (None, 260, 260, 19  0           ['up_sampling2d_190[0][0]',
#                                 2)                                'conv2d_1391[0][0]']
#
#  conv2d_1401 (Conv2D)           (None, 260, 260, 64  110656      ['concatenate_190[0][0]']
#                                 )
#
#  conv2d_1402 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1401[0][0]']
#                                 )
#
#  conv2d_1403 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1402[0][0]']
#                                 )
#
#  up_sampling2d_191 (UpSampling2  (None, 520, 520, 64  0          ['conv2d_1403[0][0]']
#  D)                             )
#
#  concatenate_191 (Concatenate)  (None, 520, 520, 11  0           ['up_sampling2d_191[0][0]',
#                                 2)                                'conv2d_1388[0][0]']
#
#  conv2d_1404 (Conv2D)           (None, 520, 520, 48  48432       ['concatenate_191[0][0]']
#                                 )
#
#  conv2d_1405 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1404[0][0]']
#                                 )
#
#  conv2d_1406 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1405[0][0]']
#                                 )
#
#  conv2d_1407 (Conv2D)           (None, 520, 520, 1)  49          ['conv2d_1406[0][0]']
#
#  cropping2d_63 (Cropping2D)     (None, 512, 512, 1)  0           ['conv2d_1407[0][0]']
#
#  input_128 (InputLayer)         [(None, 512, 512, 1  0           []
#                                 )]
#
#  add_63 (Add)                   (None, 512, 512, 1)  0           ['cropping2d_63[0][0]',
#                                                                   'input_128[0][0]']
#
# ==================================================================================================
# Total params: 3,000,625
# Trainable params: 3,000,625
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (512, 512, 152) (512, 512, 152)
# (179, 512, 512) (179, 512, 512)
# (179, 512, 512, 2)
# Model: "model_64"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_129 (InputLayer)         [(None, 512, 512, 2  0           []
#                                 )]
#
#  zero_padding2d_64 (ZeroPadding  (None, 520, 520, 2)  0          ['input_129[0][0]']
#  2D)
#
#  conv2d_1408 (Conv2D)           (None, 520, 520, 48  912         ['zero_padding2d_64[0][0]']
#                                 )
#
#  conv2d_1409 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1408[0][0]']
#                                 )
#
#  conv2d_1410 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1409[0][0]']
#                                 )
#
#  max_pooling2d_192 (MaxPooling2  (None, 260, 260, 48  0          ['conv2d_1410[0][0]']
#  D)                             )
#
#  conv2d_1411 (Conv2D)           (None, 260, 260, 64  27712       ['max_pooling2d_192[0][0]']
#                                 )
#
#  conv2d_1412 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1411[0][0]']
#                                 )
#
#  conv2d_1413 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1412[0][0]']
#                                 )
#
#  max_pooling2d_193 (MaxPooling2  (None, 130, 130, 64  0          ['conv2d_1413[0][0]']
#  D)                             )
#
#  conv2d_1414 (Conv2D)           (None, 130, 130, 12  73856       ['max_pooling2d_193[0][0]']
#                                 8)
#
#  conv2d_1415 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1414[0][0]']
#                                 8)
#
#  conv2d_1416 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1415[0][0]']
#                                 8)
#
#  max_pooling2d_194 (MaxPooling2  (None, 65, 65, 128)  0          ['conv2d_1416[0][0]']
#  D)
#
#  conv2d_1417 (Conv2D)           (None, 65, 65, 256)  295168      ['max_pooling2d_194[0][0]']
#
#  conv2d_1418 (Conv2D)           (None, 65, 65, 256)  590080      ['conv2d_1417[0][0]']
#
#  conv2d_1419 (Conv2D)           (None, 65, 65, 256)  590080      ['conv2d_1418[0][0]']
#
#  up_sampling2d_192 (UpSampling2  (None, 130, 130, 25  0          ['conv2d_1419[0][0]']
#  D)                             6)
#
#  concatenate_192 (Concatenate)  (None, 130, 130, 38  0           ['up_sampling2d_192[0][0]',
#                                 4)                                'conv2d_1416[0][0]']
#
#  conv2d_1420 (Conv2D)           (None, 130, 130, 12  442496      ['concatenate_192[0][0]']
#                                 8)
#
#  conv2d_1421 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1420[0][0]']
#                                 8)
#
#  conv2d_1422 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1421[0][0]']
#                                 8)
#
#  up_sampling2d_193 (UpSampling2  (None, 260, 260, 12  0          ['conv2d_1422[0][0]']
#  D)                             8)
#
#  concatenate_193 (Concatenate)  (None, 260, 260, 19  0           ['up_sampling2d_193[0][0]',
#                                 2)                                'conv2d_1413[0][0]']
#
#  conv2d_1423 (Conv2D)           (None, 260, 260, 64  110656      ['concatenate_193[0][0]']
#                                 )
#
#  conv2d_1424 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1423[0][0]']
#                                 )
#
#  conv2d_1425 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1424[0][0]']
#                                 )
#
#  up_sampling2d_194 (UpSampling2  (None, 520, 520, 64  0          ['conv2d_1425[0][0]']
#  D)                             )
#
#  concatenate_194 (Concatenate)  (None, 520, 520, 11  0           ['up_sampling2d_194[0][0]',
#                                 2)                                'conv2d_1410[0][0]']
#
#  conv2d_1426 (Conv2D)           (None, 520, 520, 48  48432       ['concatenate_194[0][0]']
#                                 )
#
#  conv2d_1427 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1426[0][0]']
#                                 )
#
#  conv2d_1428 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1427[0][0]']
#                                 )
#
#  conv2d_1429 (Conv2D)           (None, 520, 520, 1)  49          ['conv2d_1428[0][0]']
#
#  cropping2d_64 (Cropping2D)     (None, 512, 512, 1)  0           ['conv2d_1429[0][0]']
#
#  input_130 (InputLayer)         [(None, 512, 512, 1  0           []
#                                 )]
#
#  add_64 (Add)                   (None, 512, 512, 1)  0           ['cropping2d_64[0][0]',
#                                                                   'input_130[0][0]']
#
# ==================================================================================================
# Total params: 3,000,625
# Trainable params: 3,000,625
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (512, 512, 179) (512, 512, 179)
# (142, 512, 512) (142, 512, 512)
# (142, 512, 512, 2)
# Model: "model_65"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_131 (InputLayer)         [(None, 512, 512, 2  0           []
#                                 )]
#
#  zero_padding2d_65 (ZeroPadding  (None, 520, 520, 2)  0          ['input_131[0][0]']
#  2D)
#
#  conv2d_1430 (Conv2D)           (None, 520, 520, 48  912         ['zero_padding2d_65[0][0]']
#                                 )
#
#  conv2d_1431 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1430[0][0]']
#                                 )
#
#  conv2d_1432 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1431[0][0]']
#                                 )
#
#  max_pooling2d_195 (MaxPooling2  (None, 260, 260, 48  0          ['conv2d_1432[0][0]']
#  D)                             )
#
#  conv2d_1433 (Conv2D)           (None, 260, 260, 64  27712       ['max_pooling2d_195[0][0]']
#                                 )
#
#  conv2d_1434 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1433[0][0]']
#                                 )
#
#  conv2d_1435 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1434[0][0]']
#                                 )
#
#  max_pooling2d_196 (MaxPooling2  (None, 130, 130, 64  0          ['conv2d_1435[0][0]']
#  D)                             )
#
#  conv2d_1436 (Conv2D)           (None, 130, 130, 12  73856       ['max_pooling2d_196[0][0]']
#                                 8)
#
#  conv2d_1437 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1436[0][0]']
#                                 8)
#
#  conv2d_1438 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1437[0][0]']
#                                 8)
#
#  max_pooling2d_197 (MaxPooling2  (None, 65, 65, 128)  0          ['conv2d_1438[0][0]']
#  D)
#
#  conv2d_1439 (Conv2D)           (None, 65, 65, 256)  295168      ['max_pooling2d_197[0][0]']
# ...
#
#  conv2d_1464 (Conv2D)           (None, 130, 130, 12  442496      ['concatenate_198[0][0]']
#                                 8)
#
#  conv2d_1465 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1464[0][0]']
#                                 8)
#
#  conv2d_1466 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1465[0][0]']
#                                 8)
#
#  up_sampling2d_199 (UpSampling2  (None, 260, 260, 12  0          ['conv2d_1466[0][0]']
#  D)                             8)
#
#  concatenate_199 (Concatenate)  (None, 260, 260, 19  0           ['up_sampling2d_199[0][0]',
#                                 2)                                'conv2d_1457[0][0]']
#
#  conv2d_1467 (Conv2D)           (None, 260, 260, 64  110656      ['concatenate_199[0][0]']
#                                 )
#
#  conv2d_1468 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1467[0][0]']
#                                 )
#
#  conv2d_1469 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1468[0][0]']
#                                 )
#
#  up_sampling2d_200 (UpSampling2  (None, 520, 520, 64  0          ['conv2d_1469[0][0]']
#  D)                             )
#
#  concatenate_200 (Concatenate)  (None, 520, 520, 11  0           ['up_sampling2d_200[0][0]',
#                                 2)                                'conv2d_1454[0][0]']
#
#  conv2d_1470 (Conv2D)           (None, 520, 520, 48  48432       ['concatenate_200[0][0]']
#                                 )
#
#  conv2d_1471 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1470[0][0]']
#                                 )
#
#  conv2d_1472 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1471[0][0]']
#                                 )
#
#  conv2d_1473 (Conv2D)           (None, 520, 520, 1)  49          ['conv2d_1472[0][0]']
#
#  cropping2d_66 (Cropping2D)     (None, 512, 512, 1)  0           ['conv2d_1473[0][0]']
#
#  input_134 (InputLayer)         [(None, 512, 512, 1  0           []
#                                 )]
#
#  add_66 (Add)                   (None, 512, 512, 1)  0           ['cropping2d_66[0][0]',
#                                                                   'input_134[0][0]']
#
# ==================================================================================================
# Total params: 3,000,625
# Trainable params: 3,000,625
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (512, 512, 156) (512, 512, 156)
# (165, 512, 512) (165, 512, 512)
# (165, 512, 512, 2)
# Model: "model_67"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_135 (InputLayer)         [(None, 512, 512, 2  0           []
#                                 )]
#
#  zero_padding2d_67 (ZeroPadding  (None, 520, 520, 2)  0          ['input_135[0][0]']
#  2D)
#
#  conv2d_1474 (Conv2D)           (None, 520, 520, 48  912         ['zero_padding2d_67[0][0]']
#                                 )
#
#  conv2d_1475 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1474[0][0]']
#                                 )
#
#  conv2d_1476 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1475[0][0]']
#                                 )
#
#  max_pooling2d_201 (MaxPooling2  (None, 260, 260, 48  0          ['conv2d_1476[0][0]']
#  D)                             )
#
#  conv2d_1477 (Conv2D)           (None, 260, 260, 64  27712       ['max_pooling2d_201[0][0]']
#                                 )
#
#  conv2d_1478 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1477[0][0]']
#                                 )
#
#  conv2d_1479 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1478[0][0]']
#                                 )
#
#  max_pooling2d_202 (MaxPooling2  (None, 130, 130, 64  0          ['conv2d_1479[0][0]']
#  D)                             )
#
#  conv2d_1480 (Conv2D)           (None, 130, 130, 12  73856       ['max_pooling2d_202[0][0]']
#                                 8)
#
#  conv2d_1481 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1480[0][0]']
#                                 8)
#
#  conv2d_1482 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1481[0][0]']
#                                 8)
#
#  max_pooling2d_203 (MaxPooling2  (None, 65, 65, 128)  0          ['conv2d_1482[0][0]']
#  D)
#
#  conv2d_1483 (Conv2D)           (None, 65, 65, 256)  295168      ['max_pooling2d_203[0][0]']
#
#  conv2d_1484 (Conv2D)           (None, 65, 65, 256)  590080      ['conv2d_1483[0][0]']
#
#  conv2d_1485 (Conv2D)           (None, 65, 65, 256)  590080      ['conv2d_1484[0][0]']
#
#  up_sampling2d_201 (UpSampling2  (None, 130, 130, 25  0          ['conv2d_1485[0][0]']
#  D)                             6)
#
#  concatenate_201 (Concatenate)  (None, 130, 130, 38  0           ['up_sampling2d_201[0][0]',
#                                 4)                                'conv2d_1482[0][0]']
#
#  conv2d_1486 (Conv2D)           (None, 130, 130, 12  442496      ['concatenate_201[0][0]']
#                                 8)
#
#  conv2d_1487 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1486[0][0]']
#                                 8)
#
#  conv2d_1488 (Conv2D)           (None, 130, 130, 12  147584      ['conv2d_1487[0][0]']
#                                 8)
#
#  up_sampling2d_202 (UpSampling2  (None, 260, 260, 12  0          ['conv2d_1488[0][0]']
#  D)                             8)
#
#  concatenate_202 (Concatenate)  (None, 260, 260, 19  0           ['up_sampling2d_202[0][0]',
#                                 2)                                'conv2d_1479[0][0]']
#
#  conv2d_1489 (Conv2D)           (None, 260, 260, 64  110656      ['concatenate_202[0][0]']
#                                 )
#
#  conv2d_1490 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1489[0][0]']
#                                 )
#
#  conv2d_1491 (Conv2D)           (None, 260, 260, 64  36928       ['conv2d_1490[0][0]']
#                                 )
#
#  up_sampling2d_203 (UpSampling2  (None, 520, 520, 64  0          ['conv2d_1491[0][0]']
#  D)                             )
#
#  concatenate_203 (Concatenate)  (None, 520, 520, 11  0           ['up_sampling2d_203[0][0]',
#                                 2)                                'conv2d_1476[0][0]']
#  conv2d_1492 (Conv2D)           (None, 520, 520, 48  48432       ['concatenate_203[0][0]']
#                                 )
#
#  conv2d_1493 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1492[0][0]']
#                                 )
#
#  conv2d_1494 (Conv2D)           (None, 520, 520, 48  20784       ['conv2d_1493[0][0]']
#                                 )
#
#  conv2d_1495 (Conv2D)           (None, 520, 520, 1)  49          ['conv2d_1494[0][0]']
#
#  cropping2d_67 (Cropping2D)     (None, 512, 512, 1)  0           ['conv2d_1495[0][0]']
#
#  input_136 (InputLayer)         [(None, 512, 512, 1  0           []
#                                 )]
#
#  add_67 (Add)                   (None, 512, 512, 1)  0           ['cropping2d_67[0][0]',
#                                                                   'input_136[0][0]']
#
# ==================================================================================================
# Total params: 3,000,625
# Trainable params: 3,000,625
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (512, 512, 165) (512, 512, 165)
